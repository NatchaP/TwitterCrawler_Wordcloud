# %%
# - * - coding: UTF-8 - * -
import asyncio
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import MySQLdb
import time
import json
import argparse
import string
import re,os
import os
from os import path
from wordcloud import WordCloud
import re
from threading import Thread
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
stop_words = set(stopwords.words('english')) 

consumer_key = 'xxxx'
consumer_secret = 'xxxx'
access_token = 'xxxx'
access_token_secret = 'xxxx'

conn = MySQLdb.connect("yourConnection","username","password","database", use_unicode=True, charset="utf8")
c = conn.cursor()


#consumer key, consumer secret, access token, access secret.
ckey=consumer_key
csecret=consumer_secret
atoken=access_token
asecret=access_token_secret

class listener(StreamListener):

    def on_data(self, data):
        all_data = json.loads(data)
        
        tweet = all_data["text"]
        tweet = re.sub(r'http\S+', '', tweet)
        tweet = re.sub(r'RT @\S+\:$','',tweet)
        tweet = re.sub('RT @[^\s]+','',tweet)
        tweet = re.sub(r'[^a-zA-Z ]+', '', tweet)
        print(tweet)
        username = all_data["user"]["screen_name"]
        
        #print((username,tweet))
        c.execute("INSERT INTO tweets (username, tweet) VALUES (%s,%s)",(username, tweet))

        conn.commit()

        
        
        return True

    def on_error(self, status):
        print (status)
        
    def streamTwitter(self):
        auth = OAuthHandler(ckey, csecret)
        auth.set_access_token(atoken, asecret)

        twitterStream = Stream(auth, listener())
        twitterStream.filter(languages=["en"], track=["#ResignTrump"], async=True) #ถ้าจาก Hashtag ให้ใส่ # ถ้าคำธรรมดา ไม่ต้องใส่ก็ได้ 
        #https://developer.twitter.com/en/docs/tweets/rules-and-filtering/overview/standard-operators.html
        
    
    def selectData(self):
        d = path.dirname(__file__) if "__file__" in locals() else os.getcwd()

        text = ""

        conn = MySQLdb.connect("localhost","root","intranet","tweet", use_unicode=True, charset="utf8")
        c = conn.cursor()

        c.execute("SELECT tweet FROM tweets")

        myresult = c.fetchall()
        #print (type(myresult))
        for x in myresult:
            #print(x[0])
            text = text +" "+ x[0]
        
        from nltk.tokenize import word_tokenize 
        text = text.lower()
        word_tokens = word_tokenize(text) 
        filter_text = [w for w in word_tokens if not w in stop_words] 
        filter_text = []
        for w in word_tokens:
            if w not in stop_words: 
                filter_text.append(w)
        text = ""
        for s in filter_text:
            text = text+" "+s
        
        return text
    
    def genWC(self):
        b =  listener()
        text = b.selectData()
        # Generate a word cloud image
        wordcloud = WordCloud().generate(text)

        # Display the generated image:
        import matplotlib.pyplot as plt
        plt.imshow(wordcloud, interpolation='bilinear')
        plt.axis("off")
        plt.show(block=False)
        plt.pause(3)
        plt.close()
        

async def myCoroutine():
    a = listener()
    #a.genWC()
    await asyncio.sleep(5)
    a.streamTwitter()

def main():
    loop = asyncio.get_event_loop()
    loop.run_until_complete(myCoroutine())
    loop.close()

if __name__ == '__main__':
    main()
    
#if __name__ == '__main__':
#    a = listener()
#    Thread(target = a.genWC()).start()
#    Thread(target = a.streamTwitter()).start()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\nephilz\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-5e02913c9237> in <module>()
#     127
#     128 if __name__ == '__main__':
# --> 129     main()
#     130
#     131 #if __name__ == '__main__':
#
# <ipython-input-1-5e02913c9237> in main()
#     123 def main():
#     124     loop = asyncio.get_event_loop()
# --> 125     loop.run_until_complete(myCoroutine())
#     126     loop.close()
#     127
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_until_complete(self, future)
#     453         future.add_done_callback(_run_until_complete_cb)
#     454         try:
# --> 455             self.run_forever()
#     456         except:
#     457             if new_task and future.done() and not future.cancelled():
#
# ~\Anaconda3\lib\asyncio\base_events.py in run_forever(self)
#     407         self._check_closed()
#     408         if self.is_running():
# --> 409             raise RuntimeError('This event loop is already running')
#     410         if events._get_running_loop() is not None:
#     411             raise RuntimeError(
#
# RuntimeError: This event loop is already running
# Lets send him packing
#  malcolmnancefan MalcolmNance I agree  He is a danger to our country and should be removed however we can  ResignT
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Why is it that we dont have an individual with this type of compassion and dedication to truth honor and a sincere commi
#  The investigations team at The Democratic Coalition proved Carter Page was a liar with the release of the video below Page ha
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  realDonaldTrump You dont seem to know anyone do you A sure sign of dementia TrumpResign ResignTrump TrumpShutd
#  As a US Army soldier i am required to work without being paid during a government shut down If this lasts long enough how a
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  I cant believe our Govt is shut down because Trump wants a wallA wall folks A literal wall Not because theyr
#  Merry XMas realDonaldTrumpAny way you can retweet this tweet in between eating a BigMac and drinking a little too
# realDonaldTrump Allies express concern over James Mattis resignationResignTrump TrumpShutdown
#  Its time Domain for sale on GoDaddy proceeds dedicated to RAICESTEXAS Everyone wins  TrumpResign ResignTrumpT
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  Just for shits and giggles since the incontinent impotent mushroom knobbed man baby realDonaldTrump is so upset abou
#  acupoker JackBuckman Why does he want B when the wall will cost B Is he going to suck America dry B at a time or hold u
# realDonaldTrump I honestly thought this was a parody account and laughed and laughed and then I stopped and when I
#  This is currently being projected on to the Powell Street train station entrance in San Francisco TrumpResign ResignTrum
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  Wow Thats so effing presidential of Trump Zero points for yet another temper tantrum government shutdown ResignTrump
#  The Democratic Coalition has fought back against every corrupt Republican in Congress Like when we filed multiple House Ethics
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  itsreallyalexb One really does reap what they sow ResignTrumpTrumpResign
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  On todays episode of I DONT GIVE A FUCKYesterday the number  worldwide trend was TrumpResign amp today the number  wor
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  WAIT   WHAT
#  The Democratic Coalition is the same group that made the Boycott Trump app Remember that We even got a shout out on SNLUpdat
#  This proud TrumpsShutdown is a distraction for the tanking economy which is a distraction to the Mattis fuck you which
# Resign you traitorMisogynistTax CheatFake immoralfatuglyserial Liar
#  Day  amp the KremlinAnnex is STILL going strongTheyre doing this for US people  show them your appreciation by liking
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  timmyturmoil Already follow you but Im fucking royally disgusted by Trump amp his GOP enabler sycophants ResignTrump
#  ResignTrump by his own standards hes unfit to be in the Oval Office TrumpResign
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# realDonaldTrump Unfortunately you will never measure uo to Jim MattisGull of humilty and graceWords which you
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  Evangelicals say Donald Trump was sent to us by God Anybody know Gods return policy ResignTrump
#  Imagine being so incompetent you couldnt even get some REAL bills to sign for your FAKE billsigning photo op Thats wha
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  I agree I am  yo I thought my retirement would be joyous Ive protested many challenges as you have I wish I didnt
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
# Love our PREZ
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  Why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp w
#  Showing up to the ResignTrump party
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  Donald Trumps day so far Announces hes in the White House Announces hes eating lunch The bar really is set thi
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump youll never be a real leader Youre a failure
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  Older article in need of revistingState Dept Was Granted  Million to Fight Russian Meddling It Has Spent C
#  The Democratic Coalition is the same group who reported Michael Flynn to the DoJ for not registering as a foreign agent for Tur
#  Yes please show us how to remove a president who has shown gross incompetence Asking for a few million friendsTru
#  realDonaldTrump Individual is too afraid to go to sleep in case the looming nightmare of impeachment creeps into his h
#  hr poll who do you think is responsible for the Shutdown of government realDonaldTrump or SenSchumerPlease v
#  hr poll who do you think is responsible for the Shutdown of government realDonaldTrump or SenSchumerPlease v
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
# WINNING  TrumpResignResignTrumpTrumpShutDownTrumpLiftsSanctions
#  WAIT   WHAT
#  TrumpShutdown can also be interpreted as TrumpPullout since he bankrupts and bails out of everything including the g
# I feel like were on a sinking Titanic We have a crooked lying amp sociopathic president with multiple ongoing inve
#  malcolmnancefan MalcolmNance I agree  He is a danger to our country and should be removed however we can  ResignT
#  How long is jack gonna keep the ResignTrump fake trendingPathetic
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
# DearAuntCrabby VictoriaInTX realDonaldTrump Dear Aunt CrabbyStop being a bitchand follow me back alreadyI m
#  siano ResignTrump TrumpChristmasShutdown  TrumpResigns  ReasonsNotToBuildTheWall  RIGHT HERE  ht
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  How to Play TrumpResign Retweet a tweet with the hashtag TrumpResign Create your own tweet with TrumpResign Kee
# I hope you will like it Check this out   ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  acupoker JackBuckman Why does he want B when the wall will cost B Is he going to suck America dry B at a time or hold u
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  SteveScalise Nope Not true Republicans are so committed to propping up an out of control unstable unhinged corrupt
# realDonaldTrump No you are the least popular president that was ever elected and you are as dumb as a doorknob S
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  realDonaldTrump Yep Great job Mr Art of the DealResignTrump TrumpChristmasShutdown
# So Resisters I need a follower boost First time I have done this so please help me outKeyword  FBRParty
#  Illegitimate Traitor TrumpResign ResignTrump TrumpResigns Russia Gloats Trump Is Ours Again
# NancyPelosi she will fix it  We do not have to waste billions on the traitor antique ideas  ResignTrump
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Hey everyoneJust a reminder  Trump is PROUD of this Government ShutdownResignTrump TrumpShutdown
#  Normally tweeting that president should resign would have zero meaning But because the lunatic in the White House is a
#  Yes please show us how to remove a president who has shown gross incompetence Asking for a few million friendsTru
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# realDonaldTrump But the rest of us arent fooled by the lies youre incessantly spouting in an effort to convince
#  I bid you all a farewell Goodnight Pleasant dreams ResignTrump  TrumpResigns  Resist
# Ironhorse Either way works for me I like TrumpResign but sometimes I feel like ResignTrump works betterHuh
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  First TrumpResign was a top trend now ResignTrump is creeping its way up there I think the people have spoken
#  Cant disagree with Trump on this
#  Sounds right
#  Donald Trumps day so far Announces hes in the White House Announces hes eating lunch The bar really is set thi
#  Attention resistance We need to stick together amp support each other Please retweetFBRParty FBR  Follow Retwee
#  mcspocky Thats shocking How did they manage to do it so cheaply Melania can crack a million just for afternoon tea RE
# Gotta love those great enablers of violence against women in the GOP   They would rather throw a temper tantrum a
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# POTUS doesnt comprehend what bipartisan means Thinks it means he gets his way TrumpResign ResignTrump
#  ResignTrump is now number one on Twitter again I think our Family had more than a little to do with that   Youre the b
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Cant disagree with Trump on this
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# TrumpResign  RETWEETResignTrumpResignTrump ResignTrump ResignTrump ResignTrump ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# funder carbonneaumary This  movement of TrumpResign TrumpShutdown ResignTrump TrumpChristmasShutdown may no
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  Now this realDonaldTrump is SAD You should be ashamed of yourself ResignTrump TrumpResign TrumpChristmasShutdown
#  Saying thank you to ppl who have to do their job unpaid so that the rest of us can get where we want to go seems in
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  Empty paperEmpty headEmpty promisesResignTrump
#  How long is jack gonna keep the ResignTrump fake trendingPathetic
#  realDonaldTrump September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The Presiden
# I think you mean  year temper tantrum TrumpResign ResignTrump
#  AlexKatz eclecticbrotha janeosanders Dems must demand transparency Multiple years of Tax returns must be submitted BE
#  As a US Army soldier i am required to work without being paid during a government shut down If this lasts long enough how a
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Cant disagree with Trump on this
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  And if theres  under the same President then whatI wonder if we can eject him from the plant Let the aliens have him
#  Cant disagree with Trump on this
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
# How true ResignTrump TrumpResign
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  The tweets from past are enough for ResignTrump TrumpShutDown
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
# Its time to destroy the foxnews
#  Hell to tha yea ResignTrump
#  Hes fueling an epidemic of antiintellectualism via washingtonpost Editorial realDonaldTrumps shutdown stunt is an a
#  Two different tags going tonight so just in case RETWEETResignTrump TrumpResignResignTrump TrumpResignResi
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  I love how well his tweets age ResignTrump
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  Can you believe this sociopath Dont forget his name James Lankford ResignTrump
# Trump is not a true leader he should resign TrumpResign resignTrump
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  Trump if you resign now you can get to MarALago today Air Force One will give you one last complimentary ride  Resi
#  I love how well his tweets age ResignTrump
# Keep ignoring us here in America annas we arent far behindTrumpResign ResignTrump
#  We have leaders of our Party who REFUSE to give in or compromise on what we know is morally as fiscally correct A few more
#  COME ON YOU GUYS LETS MAKE IT HAPPEN RESIGNTRUMP
# like a fine wine
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  Are you following these voices RT follow share amp add to our list below Lets push ResignTrump NancyPelosiBeto
#  For as long as the TrumpShutdown is still in effect lets end every single tweet we send on any subject with the TrumpR
#  WAIT   WHAT
#  Didnt age well did it Donnie boy
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
# realDonaldTrump Great So you can pout and rage tweet even more ResignTrump
#  This was said by Trump in  ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Normally tweeting that president should resign would have zero meaning But because the lunatic in the White House is a
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
# Listen to the manrealDonaldTrump knows we need to fire realDonaldTrump
#  This is what I always assumed it meant to be a good Christian TrumpShutdown trumpresign resigntrump
# What he meant to say Trump tires his staff out because hes like a  year old
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
# realDonaldTrump Youre the shittiest president in history Everyone with half a brain hates you ResignTrump
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Why is it that we dont have an individual with this type of compassion and dedication to truth honor and a sincere commi
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Showing up to the ResignTrump party
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Normally tweeting that president should resign would have zero meaning But because the lunatic in the White House is a
# So these MAGAts actually believe Alyssa M Is for building the wallhas no ideA what sarcasm is as you will not
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# realDonaldTrump Might as well get the whole lot trending so please retweetTrumpsShutdownTrumpResign
#  BTW  are you guys doing your part to keep ResignTrump trending Please post it daily until the CheetoInChief is wear
# Yes he isResigntrumpTicToclTicTock TritorstRumpsAndGOPLockThemAllUpIvankaToo NeverEverVoteGOP
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  tRumpChristmasShutdownResigntRumpLike this one
#  ResignTrump TrumpResign  America is done with the dotard Time to go Donnie
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  First TrumpResign was a top trend now ResignTrump is creeping its way up there I think the people have spoken
#  I love how well his tweets age ResignTrump
# realDonaldTrump Really You think the peoplemof this great country are as Fing stupid as you are We can see they
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# I like presidential families who arent crime syndicates TrumpResign Resigntrump trumpResigns
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  realDonaldTrump Everything you say and do is narcissistic and selfservingIts redefining what it means to be an Ameri
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  Merry XMas realDonaldTrumpAny way you can retweet this tweet in between eating a BigMac and drinking a little too
#  I bid you all a farewell Goodnight Pleasant dreams ResignTrump  TrumpResigns  Resist
# realDonaldTrump Unfortunately you will never measure up to Jim MattisFull of humilty and graceWords which you
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Donald Trump Will Resign and It Will Happen Suddenly Predicts Keith OlbermannLook its nice to hear that but predic
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  Well Trump just beat Obama at another thingMore Government ShutdownsSo Much WINNINGAnd hes proud of it
# RETWEETResignTrumpResignTrump ResignTrump ResignTrump ResignTrump ResignTrump ResignTrump
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  Trump should resign ResignTrump TrumpResign
#  Why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp w
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  WAIT   WHAT
#  Can you believe this sociopath Dont forget his name James Lankford ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Donald Trump Will Resign and It Will Happen Suddenly Predicts Keith OlbermannLook its nice to hear that but predic
#  I love how well his tweets age ResignTrump
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  This was said by Trump in  ResignTrump
# another reasonTrumpResign ResignTrump
# There nothing good thatll come out of the shutdown in the long run for Trump It only served to bolster a renewed
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Didnt age well did it Donnie boy
#  NancyPelosi she will fix it  We do not have to waste billions on the traitor antique ideas  ResignTrump
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  This was said by Trump in  ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# realDonaldTrump YOU defeated ISIS No their pullback was accomplished by people like Brett McGurk Who you didnt
#  Showing up to the ResignTrump party
# realDonaldTrump You are in the White House watching tv drinking Diet Coke and rage tweeting  RESIGNTRUMP TRUMPRESIGN
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
# realDonaldTrump Megalomaniachave you lost your mind Do everyone a favor ResignTrump
#  New Chief of Staff TrumpResign ResignTrump TrumpShutdown
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  ResignTrump Just fucking resign because this photo is far worse than that OTHER photo
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  He is on his third Chief of StaffHis third National Security AdviserHis sixth Communications DirectorHis second Secretary
#  Uhh I dont think these two men are the SAME men Someone America maybe needs to do some facial recognition on them Th
#  This Presidency is a joke And a dangerous oneResignTrump
#  A Shutdown falls on the Presidents lack of leadership He cant even control his party and get people together in a room
#  ResignTrumpTrumpResignTrumpResigns ResignTrumpTrumpResignTrumpResignsResignTrumpTrumpResignTrumpResigns R
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  This was said by Trump in  ResignTrump
#  Two different tags going tonight so just in case RETWEETResignTrump TrumpResignResignTrump TrumpResignResi
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump youll never be a real leader Youre a failure
#  WAIT   WHAT
# This is tyranny of talk radio hosts right Limbaugh and Coulter blamed for Trumps shutdown
#  EdKrassen Save democracyIndictTrumpNow  TrumpResign ResignTrump TrumpIsTheEnemyOfThePeople
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# ThesTaughtMe SaturdayMorning WhatITrulyWantIs ResignTrump AVeryJoeBobChristmas socialcheap  All social me
# Oops
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump youll never be a real leader Youre a failure
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  Morning I wanna get on the twitter trend parade too ResignTrump TrumpResigns ResignTrump
#  Why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp w
#  COME ON YOU GUYS LETS MAKE IT HAPPEN RESIGNTRUMP
# realDonaldTrump No words To describe the BLATANT INCOMPETENCE Simply no words ResignTrump thAmendmentNow
#  This was said by Trump in  ResignTrump
# Hey Donald Your Twitter pic looks abt  years old You know it aint a dating sight dont you TrumpResign ResignTrump
# TrumpResign Disgusting glutton nanbsby wants a wall  Fuk tRump ResignTrump
#  tRumpShutdown ResigntRumpThe Trumps Just Love Spending Taxpayer Money On Lavish Vacations
#  hr poll who do you think is responsible for the Shutdown of government realDonaldTrump or SenSchumerPlease v
#  I like presidential families who arent crime syndicates TrumpResign Resigntrump trumpResigns
#  I bid you all a farewell Goodnight Pleasant dreams ResignTrump  TrumpResigns  Resist
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  While you still have the Senate AND the House GOP leadership is to blame for the TrumpShutdownAnd Paul Ryan will wear
#  If you didnt believe THAT EVERYTHING  is politics amp ControlledNarrative by LibMedia amp NWO the top trends on Twitter t
#  On my flight home I asked a woman who didnt know Im a member of Congress Are we almost there yet She replied
#  How true ResignTrump TrumpResign
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  LaurieGT MikelJollett Empathy So underutilized We need much more GOPFail ResignTrump
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  So these MAGAts actually believe Alyssa M Is for building the wallhas no ideA what sarcasm is as you will notice on
#  yes to all  MERRY CHRISTMAS
#  Why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp w
#  While you still have the Senate AND the House GOP leadership is to blame for the TrumpShutdownAnd Paul Ryan will wear
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  The tweets from past are enough for ResignTrump TrumpShutDown
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Wondering if walls work Since Israel put up their border wall illeagal immigration and suicide bombings have gone to
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  realDonaldTrump LEASTPOPULARPRESIDENTEVERAnd its not even closeResignTrumpTrumpResign
# realDonaldTrump    Nice one Rosie
# cspan NJTrainDelays Dear realDonaldTrump  we blame you Btw did you see ResignTrump is still trending
# realDonaldTrump ResignTrump NotMyPresident YouSuck YourethegrandstanderGo Away Far Far Away and never come back
#  brikeilarcnn Please realDonaldTrump do the entire world a favor and just TrumpResign Then we can all do a HappyDance
# realDonaldTrump RT Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
# ThesTaughtMe SaturdayMorning WhatITrulyWantIs ResignTrump AVeryJoeBobChristmas socialcheap  All social me
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  For as long as the TrumpShutdown is still in effect lets end every single tweet we send on any subject with the TrumpR
#  Mr Art of the Deal is incapable of making a dealHell bankrupt the country like all of his businessesWe do NOT negotiate
#  realDonaldTrump potus flotus VP WhiteHouseStopthrowingshitatfansthereisenoughtogoaroundTrumpResi
#  Cant disagree with Trump on this
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  realDonaldTrump gskh Youre the most hated fake president in history trumpresign trumpresign trumpresign trump
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  mcspocky funder Three for the price of one TrumpResign ResignTrump TrumpResigns I like to add TrumpChristmasShutdo
#  This is the way Republicans made America great before realDonaldTrump ResignTrump TrumpResign
#  realDonaldTrump On December   in the wake of President Trumps decision to withdraw troops from Syria McGurk anno
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Mueller looking for collusion with Russia is like OJ looking for Nicoles killerMAGA tcot FoxNews ResignTrump
# realDonaldTrump As long as youre there how about considering ResignTrump TrumpResignNOW TrumpsShutdown
#  I agree I am  yo I thought my retirement would be joyous Ive protested many challenges as you have I wish I didnt
# funder The GOP are a group of wasteless skinamp no brainsTRUMPRESIGN TRUMPSHUTDOWN RESIGNTRUMP INDIVIDUAL
# realDonaldTrump Washingtons allies express concern over military shake up after Mattis resignationResignTrump
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
# We Need Wall KAOS chaos agent realDonaldTrump is SO delusional that he thinks not only will it get built but it
# WE THE PEOPLE WANT HIMOUT OF OUR WH OUT OF OUR LIVES HAD HE NOT ALREADY DESTROYED ENOUGH WHAT WILL IT TAKE
# Its nice to see Trump is continuing the grand ol Republican tradition of not knowing things GOPfail ResignTrump
#  Donald Trumps day so far Announces hes in the White House Announces hes eating lunch The bar really is set thi
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
# realDonaldTrump Youre a delusional fool TrumpChristmasShutdown TrumpResigns ResignTrump ReasonsNotToBuildTheWall
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  Take a good look at this  pictures watch the ears are they the same the man currently presiding over the affairs of Nige
#  You will not win said Pelosi The fact is you do not have the votes in the HouseTrump makes Democrats eat th
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  I love how well his tweets age ResignTrump
#  How true ResignTrump TrumpResign
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  So Resisters I need a follower boost First time I have done this so please help me outKeyword  FBRPartyResistre
#  Showing up to the ResignTrump party
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Donald Trumps day so far Announces hes in the White House Announces hes eating lunch The bar really is set thi
#  RT Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  realDonaldTrump So lemme get this straight your party controls the executive house and senate but we are having the thir
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  mcspocky funder You mean we should all keep tagging TrumpResign and TrumpResigns and resigntrump to keep them all t
#  The go fund me for that stupid ass wall is over  Flint still doesnt have clean water and Puerto Rico is sti
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  Congratulations to the GOP and realDonaldTrump for causing their third shutdown of the year despite holding the three branc
#  Lets start the year out great Trump can resign for Christmas call it a Christmas gift if you want We can start the
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  ResignTrump Just fucking resign because this photo is far worse than that OTHER photo
# Sounds right
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  No president is above the law because when that happens we call that a dictator ResignTrump
# DysfunctFelines TrumpResign  RETWEETResignTrumpResignTrump ResignTrump ResignTrump ResignTrump
#  realDonaldTrump merrychristmas from TrumpResignTrump ResignNow TrumpChristmasShutdown TrumpShutdown
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  ResignTrump is now number one on Twitter again I think our Family had more than a little to do with that   Youre the b
#  Barack Obama just had a highway named after him in Los Angeles  President Barack H Obama HighwayDonald
#  Yesterday the number one worldwide trend was TrumpResign Today the number one worldwide trend is ResignTrumpWhat d
#  realDonaldTrump You dont get it do you  You left everyone stranded and surprised  Its not about leaving  Its about s
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  realDonaldTrump So much smokeTrumpShutdown TrumpChristmasShutdown ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  COME ON YOU GUYS LETS MAKE IT HAPPEN RESIGNTRUMP
#  we motets are getting daring  ResignTrump
#  POTUS doesnt comprehend what bipartisan means Thinks it means he gets his way TrumpResign ResignTrump
#  Cant disagree with Trump on this
# He did nothing heroic He did nothing smart He as usual did what he though was in his own best interests That i
#  ResignTrumpTrumpResignTrumpResigns ResignTrumpTrumpResignTrumpResignsResignTrumpTrumpResignTrumpResigns R
#  mirogster firecracker MikelJollett Yeah you do the work and I wont pay you for it ResignTrump TrumpChristmasS
#  Oblivious to the fact that the overwhelming majority of Americans arent buying his bullsht  serial lying conman Trump
#  The investigations team at The Democratic Coalition proved Carter Page was a liar with the release of the video below Page ha
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  On todays episode of I DONT GIVE A FUCKYesterday the number  worldwide trend was TrumpResign amp today the number  wor
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
# realDonaldTrump You are LITERALLY the ONLY person who says it was the greatest of all time Youre not even top
#  ResignTrumpYou can do it in a letterYou can do it in a TweetGive everyoneA Christmas treatJust fly to MaraLagoWine and
#  I DID IT I got my TrumpChristmasShutdown  fedral workers HAVE TO stay home without pay  MUST WORK wi
# realDonaldTrump Just stop omgness Mueller can see these You you that rightWhat extra tools Space Force W
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  ResignTrump  Want to win one of these itemsjust follow me here and on instagram iamrocker  Retweet this and hear
#  So much corruption going on in the WhiteHouse TrumpResigns ResignTrump
# RachelMcGonagi DysfunctFelines TrumpResign  RETWEETResignTrumpResignTrump ResignTrump ResignTrump
#  Hey everyoneJust a reminder  Trump is PROUD of this Government ShutdownResignTrump TrumpShutdown
# realDonaldTrump Hes leaving because you suck at being president Also because you are a traitor to the United Sta
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
# Ill tell u whatif TrumpResign is a FACT then well make sure he has a nice wall surrounding his new home in
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  The tweets from past are enough for ResignTrump TrumpShutDown
# Hell yes TrumpResign ResignTrump
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
# MrDane Hopefully only for now resigntrump
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  A Republican POTUS a Republican Senate amp a Republican House willingly amp PROUDLY shut down the FederalGovernment  days befo
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  Cant disagree with Trump on this
# realDonaldTrump Nice blank sheet of paper posing as a billTruly hoping that Santa brings me news of your resi
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Cant disagree with Trump on this
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# Curious how poor Lindsey Graham as enabling as hes been didnt manage to secure a Cabinet position What did h
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  This was said by Trump in  ResignTrump
#  Now this realDonaldTrump is SAD You should be ashamed of yourself ResignTrump TrumpResign TrumpChristmasShutdown
#  TrumpResign Should be tweeted every hour on the hour from now until it happens ResignTrump
# TheDemCoalition TrumpResign  RETWEETResignTrumpResignTrump ResignTrump ResignTrump ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  Theres a tweet for every occasion ResignTrump
#  Merry XMas realDonaldTrumpAny way you can retweet this tweet in between eating a BigMac and drinking a little too
#  Hey everyoneJust a reminder  Trump is PROUD of this Government ShutdownResignTrump TrumpShutdown
#  This was said by Trump in  ResignTrump
# ProudDemResists Obama had a highway named after him What will be named after TrumpThats easy byebyeway TrumpResign ResignTrump
#  realDonaldTrump Im assuming that when you say your favorite President youre talking to Putin and Erdoan With  appr
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  The reason why Ill never vote democrat is illegal immigration I am  a singleissue voter when it comes to illegal
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  realDonaldTrump You won an election and are driving away those who voted for you while energizing more and more pe
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  Say it with me nowResignTrump
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Said to be one of the greatest of all timeSaid by who you fucking dipshit Ivanka Hannity Your left handTru
# realDonaldTrump youre a piece of work And by work Im mean youre a shithead
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  How true ResignTrump TrumpResign
#  Hey DonaldWhen you lose Fox and Friends I think its time to resignResignTrump
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  Trump loves to be the biggest or do the most so heres another notch for his XXXL sized belt The most government shutdown
# realDonaldTrump Favourite What an are you are Correct spelling for a Kiwi by the way We are all laughing at you
#  In a televised address the President announced a more rapid reduction than military commanders had advised Obama
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  The Democratic Coalition is trendingWho are we Were the Americans who fought back against Trump starting in early  In
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  Allow me to reintroduce you to your President for the next  yearsHe is a fighterHe is a survivorHe will outwit you
#  YOU OWN IT realDonaldTrump TrumpShutdown TrumpChristmasShutdown TrumpResign ResignTrump
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  I love how well his tweets age ResignTrump
#  Its hard for Trump and the Russians to throw us off our game when we keep changing the format of our hashtag Keep it going f
#  realDonaldTrump Youve done more damage to the USA than anyone else ResignTrump
#  Give the entire world a Christmas miracle realDonaldTrump and ResignToday ResignTrump TrumpResign ResignNow
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Two different tags going tonight so just in case RETWEETResignTrump TrumpResignResignTrump TrumpResignResi
#  Hes fueling an epidemic of antiintellectualism via washingtonpost Editorial realDonaldTrumps shutdown stunt is an a
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
# LOUDER FOR THE PEOPLE IN BACK
# ...
#  ResignTrump TrumpResign  America is done with the dotard Time to go Donnie
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Might as well get the whole lot trending so please retweetTrumpsShutdownTrumpResignResignTrumpTrumpResignsTr
# AnnCoulter Trumps Presidency in Numbers  children detained  lies amp misleading claims  ch
#  ResignTrump Resigntrump resignTrump ResignTrump ResignTrump ResignTrump ResignTrump ResignTrump ResignTrump Resig
#  Can you believe this sociopath Dont forget his name James Lankford ResignTrump
#  It has been shown over and over that not only are illegal border crossings at a  year low but both illegal and legal immigr
#  RT BettyBowers September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The President
# WorstNegotiatorEver you lost any credibility you had  Youre a thug in a suit and a dumb one at thatYou said
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
#  realDonaldTrump You have pissed off the entire country for Christmas Nice job Scrooge TrumpResign TrumpShutdown R
#  Previously Trump has said we should blame the PRESIDENT for any government shutdownNow that he is president of course he
#  IDC if trump resigns is impeached gets involuntarily committed w thA hes STILL GOING TO PRISONjust like his mobsy pal
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  I DID IT I got my TrumpChristmasShutdown  fedral workers HAVE TO stay home without pay  MUST WORK wi
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
# NASA is part of the government shutdown btw the people who flew this spacecraft over  miles to take th
#  Should PresidentTrump Resign Remember we get Pence if Trump resigns Mother could end up as VP Vote comment
#  Yes please show us how to remove a president who has shown gross incompetence Asking for a few million friendsTru
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Evangelicals say Donald Trump was sent to us by God Anybody know Gods return policy ResignTrump
#  Can you believe this sociopath Dont forget his name James Lankford ResignTrump
#  WAIT   WHAT
# thehill Trumps Presidency in Numbers  children detained  lies amp misleading claims  child
#  Normally tweeting that president should resign would have zero meaning But because the lunatic in the White House is a
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# MuellerSheWrote BarbL realDonaldTrump ResignTrump  you are a feckless miserable narcissist You are no pat
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
# BeschlossDC asmallworld That SURELY leaves out realDonaldTrump whos currently squatting in the White House as
#  Found at tRumpShutdown ResignTrump A closed circuit video as leaked after the White House meeting
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  HELL YES my  year old republican father LEFT the party to become a libertarian resist resistance ResignTrump RE
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  If youre going to rejoice over the refusal of refugee families at our borders you probably shouldnt be sweetly singi
#  ResignTrumpYet the source of the money coming to Trump wasnt really that mysterious Most investigators believed
#  The overwhelming majority of Americans have one answer for lunatic bigot Trumps government shutdown and blackmail of the
# Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets  via HuffPostPol
# Unbeknownst to the world it sits in the unrecorded Dantes th circle and no this isnt a comedy UN cnni
# AnnCoulter Trumps Presidency in Numbers  children detained  lies amp misleading claims  ch
# beautifully said TrumpResign ResignTrump TrumpShutdown TrumpChristmasShutdown realDonaldTrump
#  This proud TrumpsShutdown is a distraction for the tanking economy which is a distraction to the Mattis fuck you which
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  Hey realDonaldTrump Yesterday the  topic on Twitter Was TrumpResign Today the  topic is ResignTrump  Do you se
#  Cant disagree with Trump on this
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  Imagine being disliked so much that you trend  worldwide for days Congrats realDonaldTrump youre a real winner
#  WorstNegotiatorEver you lost any credibility you had  Youre a thug in a suit and a dumb one at thatYou said Mexico w
#  Im not sure what excites me more  The fact that TrumpResign is trending on TwitterorThe fact that Trump just tweet
#  I DID IT I got my TrumpChristmasShutdown  fedral workers HAVE TO stay home without pay  MUST WORK wi
#  TrumpResign Should be tweeted every hour on the hour from now until it happens ResignTrump
#  Remember when presidents of the United States worked on behalf of the United StatesTrumpResign TrumpShutdown Re
#  Wondering if walls work Since Israel put up their border wall illeagal immigration and suicide bombings have gone to
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
# It will be soon to be MAKE PRISON GREAT AGAIN It will be lovely to see Donald Orange is the new Bla
#  We went from the greatest nation on earth to the dumbest nation on earth in  yearstrumpresign resigntrump TrumpRe
#  For the second day in a row ResignTrump is not only trending in America it is  trending globally Apparently even God
# trump resign resigntrump ResignTrump
#  All I want for Christmas is to get to  followersLets have a FUCK TRUMP FOLLOW back partyIf you hate trump an
#  REMINDERpotus is a rapisthe raped a  yo he does whatever Putin wantshe forced a government shutdownhe wont
#  God Bless realDonaldTrumpMerry Christmas POTUS WWGWGA ResignTrump TrumpResigns
#  While the ResignTrump liberals pitch their daily fit THIS is happening while Democrats refuse to fund the wall
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  Russian TV Host Americans are losers since Putin has defeated them  Trump is ours again  Res
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Normally tweeting that president should resign would have zero meaning But because the lunatic in the White House is a
#  tribelaw Hes having a mental breakSomeone must get him out of the WH NOWResignTrump
# realDonaldTrump All the people in Syria and Afghanistan who helped American Soldiers from getting them food to jo
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  For as long as the TrumpShutdown is still in effect lets end every single tweet we send on any subject with the TrumpR
#   THE NATIONAL NIGHTMARE IS GOING TO END TrumpResigns TrumpChristmasShutdown
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Responsibility is defined as the state or fact of being accountable or to blame for something   said he would be a
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  I GAVE UP  DAYS OF GOLFING TO SIGN BLANK SHEETS OF PAPER FAVORITE PRESIDENTResignTrumpTrumpResign
#  The reason why Ill never vote democrat is illegal immigration I am  a singleissue voter when it comes to illegal
#  BrillIant Sound on
# also ResignTrump AllIWantForChristmas
#  IDC if trump resigns is impeached gets involuntarily committed w thA hes STILL GOING TO PRISONjust like his mobsy pal
# Never forget trump is proud to shut the government down ResignTrump  TrumpResign  ImpeachTrump
#  stevenmnuchin realDonaldTrump You people are a revolting collection of corrupt swamp monsters Youre wrecking our econo
#  tRumpShutdown tRumpResign ResigntRumprealDonaldtRump says he is very weak
#  Trump should resign immediately Retweet if you agree Then click below to support our online campaign at TheDemCoali
#  Celebrities and lawmakers are flooding Twitter with trumpresign and resigntrump tweets
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  PaulSGundlach agavecorn TopSergeant cyngia Chieki RestlessNews riseupmoretime stevejetcity garyd Moonca
#  Wondering if walls work Since Israel put up their border wall illeagal immigration and suicide bombings have gone to
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  hr poll who do you think is responsible for the Shutdown of government realDonaldTrump or SenSchumerPlease v
#  RedTRaccoon To bad so sad  isnt hearing what he wants to hearTrumpResign TrumpShutdown ResignTrump Individual
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Showing up to the ResignTrump party
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
# Doubt the spinelessGOP will ever fire him but Id settle for TrumpResign
#  Its hard for Trump and the Russians to throw us off our game when we keep changing the format of our hashtag Keep it going f
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# Dude we can see the mirror in front of you so you can see yourself Come on now ResignTrump vanity at its greed
#  Remember who took your healthcare awayTrumpShutdown ResignTrump
#  I love how well his tweets age ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  You are signing a blank piece of paper Do you not know people can zoom in on these you cretin ResignTrump
#  So Trump has all  branches amp still shuts the government down  times in  yearsThats got to be some kind of record
#  Donald Trumps day so far Announces hes in the White House Announces hes eating lunch The bar really is set thi
#  Wondering if walls work Since Israel put up their border wall illeagal immigration and suicide bombings have gone to
#  Can you believe this sociopath Dont forget his name James Lankford ResignTrump
#  I love how well his tweets age ResignTrump
#  ResignTrumpTrumpResignTrumpResigns ResignTrumpTrumpResignTrumpResignsResignTrumpTrumpResignTrumpResigns R
#  This is a winning message Share this far amp wide ReasonsNotToBuildTheWall ResignTrump
#  I DID IT I got my TrumpChristmasShutdown  fedral workers HAVE TO stay home without pay  MUST WORK wi
#  You know if a restaurant shuts down three times in one year they dont let it reopen too many rats TrumpChristmasSh
#  Trump talking about a shutdown  ResignTrump InWordsOrLess
#  Trump will resignAmerica will rebuildWe always come backTrumpResignResignTrump
#  Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp water do
#  Responsibility is defined as the state or fact of being accountable or to blame for something   said he would be a
#  You bragged about your accomplishments at the UN realDonaldTrump  and were met with deserved laughter The top t
#  tRumpShutdown ResigntRumpIvanka Trump and Jared Kushner spent a weekend at a luxury hotel in the Dominican Republic  and
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  RT Heres why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try
# realDonaldTrump He was trying to motivate and inspire you and your administration to follow  Any takers  ResignTrump
#  Retweet if you agree Trump should resign immediately Retweet if you agree enough is enough and its time we take our cou
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
#  I would imagine it would cost much less to tear down a stupid wall than it would be to erect it Crowd sourcing may ver
#  Showing up to the ResignTrump party
#  agavecorn josefsmith RestlessNews PMatote FrnessiArk PRayada SuZiE werachula NoemyAlegria VecinoRegi
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# DonaldTrump aka SoCalled POTUS has become TheGrinch who stole American Christmas after he started
#  I GAVE UP  DAYS OF GOLFING TO SIGN BLANK SHEETS OF PAPER FAVORITE PRESIDENTResignTrumpTrumpResign
#  WAIT   WHAT
#  Why the hashtag changed from just TrumpResign Trolls promoted ResignTrump amp TrumpResigns overnight to try amp w
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Hey everyoneJust a reminder  Trump is PROUD of this Government ShutdownResignTrump TrumpShutdown
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# realDonaldTrump Maybe you can ask for a prison located in Florida at your sentencing trumpshutdown resigntrump
#  Trumps Presidency in Numbers  children detained  lies amp misleading claims  children separated
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
#  at least she has better hygiene habits than the trump familyTrumpResignResignTrumpTrumpShutDown
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
# TrumpResign Retweet it Send the message TrumpResigns ResignTrump
#  September  FOX NEWS    If there is a shutdown who should get firedTRUMP          The PresidentTrumpChr
# Currently in the White House Evacuate In our moment of triumph I think you overestimate their chances
#  The Resistance has been CRUSHING Twitters top trending hashtag over the last  hours TrumpResign has flooded Twitt
#  Dear realDonaldTrump FYI the  topic this morning on Twitterwhich you cant regulateis ResignTrump  isTrumpChrist
# I wish the adult toddler would fire himself TrumpResigns Resigntrump
#  The reason why Ill never vote democrat is illegal immigration I am  a singleissue voter when it comes to illegal
